# %%
from skimage import novice

# %%
picture = novice.open("sample.png")picture.show()

# %%
picture.format
# Out:
# 'PNG'

# %%
picture.path
# Out:
# '/home/hansenm/Documents/Personal/Software Carpentry/skimage/sample.png'

# %%
picture.size
# Out:
# (665, 500)

# %%
picture.width
# Out:
# 665

# %%
picture.size = (200, 250)

# %%
picture.show()

# %%
for pixel in picture:                  if ((pixel.red > 128) and              (pixel.x < picture.width)):        pixel.red /= 2

# %%
picture.show()

# %%
picture.modified
# Out:
# True

# %%
print picture.path
# Out:
# None

# %%
picture[0:20, 0:20] = (0, 0, 0)

# %%
picture.show()

# %%
picture.save('sample-bluegreen.jpg')

# %%
picture.path
# Out:
# '/home/hansenm/Documents/Personal/Software Carpentry/skimage/sample-bluegreen.jpg'

# %%
picture.format
# Out:
# 'JPEG'

# %%
picture.modified
# Out:
# False
